# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint

# As the dataset is divided into folders
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Creating Dataset

# %%
w,h = 250,250
batch_size = 16

train_path = 'G:\\Research\\Completed\\ICICT 2024\\xray\\train'
test_path = 'G:\\Research\\Completed\\ICICT 2024\\xray\\test'
val_path = 'G:\\Research\\Completed\\ICICT 2024\\xray\\val'

train_img_gen = ImageDataGenerator(
    rescale = 1.0/255,
    # zoom_range=0.3
    # preprocessing_function = exposure_contrast_setting
)

test_img_gen = ImageDataGenerator(
    rescale = 1.0/255,
    # preprocessing_function = exposure_contrast_setting
)

val_img_gen = ImageDataGenerator(
    rescale = 1.0/255,
    # preprocessing_function = exposure_contrast_setting
)

train_dataset = train_img_gen.flow_from_directory(
    train_path,
    target_size = (w,h),
    batch_size = batch_size,
    class_mode = 'categorical',
    shuffle = True
)

test_dataset = test_img_gen.flow_from_directory(
    test_path,
    target_size = (w,h),
    batch_size = batch_size,
    class_mode = 'categorical',
    shuffle = False
)

val_dataset = val_img_gen.flow_from_directory(
    val_path,
    target_size = (w,h),
    batch_size = batch_size,
    class_mode = 'categorical',
    shuffle = False
)
# Out:
# Found 6326 images belonging to 4 classes.
# Found 771 images belonging to 4 classes.
# Found 38 images belonging to 4 classes.

# %%
train_dataset.class_indices
# Out:
# {'COVID19': 0, 'NORMAL': 1, 'PNEUMONIA': 2, 'TURBERCULOSIS': 3}

# %% [markdown]
# # View Images

# %%
classes = ['COVID19', 'NORMAL', 'PNEUMONIA', 'TB']

for _ in range(1):
    img, label = train_dataset.next()
    print(img.shape)
    plt.title(classes[np.argmax(label[0])])
    plt.imshow(img[0])
    plt.show()
# Out:
# (16, 250, 250, 3)

# %%
train_dataset.image_shape
# Out:
# (250, 250, 3)

# %% [markdown]
# # Alexnet Architecture

# %%
# from tensorflow.keras import models
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# model = models.Sequential()

# # Convolutional layers
# model.add(Conv2D(96, (11, 11), strides=4, activation='relu', input_shape=(w, h, 3)))
# model.add(MaxPooling2D(pool_size=(3, 3), strides=2))
# model.add(Conv2D(256, (5, 5), padding='same', activation='relu'))
# model.add(MaxPooling2D(pool_size=(3, 3), strides=2))
# model.add(Conv2D(384, (3, 3), activation='relu'))
# model.add(Conv2D(384, (3, 3), activation='relu'))
# model.add(Conv2D(256, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(3, 3), strides=2))

# # Flatten layer
# model.add(Flatten())

# # Dense layers
# model.add(Dense(4096, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(4096, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(4, activation='softmax'))

# # Compile the model
# optimizer = tf.keras.optimizers.Adam(learning_rate=3e-4)
# model.compile(optimizer= optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# # Print a summary of the model architecture
# model.summary()

# %% [markdown]
# # CNN + LSTM

# %%
model = models.Sequential()

# Convolutional layers
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(w, h, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# # Reshape the output from the convolutional layers for LSTM
# model.add(layers.Reshape((-1, 128)))

# # LSTM layer
# model.add(layers.LSTM(128, return_sequences=True))

# Flatten layer
model.add(layers.Flatten())

# Dense layers
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=3e-4)
model.compile(optimizer= optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Print a summary of the model architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 248, 248, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 124, 124, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 122, 122, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 61, 61, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 59, 59, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 29, 29, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 107648)            0
#
#  dense (Dense)               (None, 512)               55116288
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 55,275,716
# Trainable params: 55,275,716
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # ResNet101_v2

# %%
# resnetModel = models.Sequential()

# ResNet_101_V2 = tf.keras.applications.ResNet101V2(
#                 include_top = False,
#                 weights="imagenet",
#                 input_shape=(w,h,3),
#                 pooling='max',
#                 classes=4
#             )

# for layer in ResNet_101_V2.layers:
#     layer.trainable = False

# resnetModel.add(ResNet_101_V2)
# resnetModel.add(layers.Flatten())
# resnetModel.add(layers.Dense(512, activation='relu'))
# resnetModel.add(layers.Dense(128, activation='relu'))
# resnetModel.add(layers.Dense(4, activation='softmax'))  # softmax is used as it is a multiclass problem

# # Compile the model
# resnetModel.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# resnetModel.summary()

# %% [markdown]
# # Mobile Net v2

# %%
# mobileModel = models.Sequential()

# MobileNetV2 = tf.keras.applications.MobileNetV2(
#                 include_top = False,
#                 weights="imagenet",
#                 input_shape=(w,h,3),
#                 pooling='max',
#                 classes=4
#             )

# for layer in MobileNetV2.layers:
#     layer.trainable = False

# mobileModel.add(MobileNetV2)
# mobileModel.add(layers.Flatten())
# mobileModel.add(layers.Dense(512, activation='relu'))
# mobileModel.add(layers.Dense(128, activation='relu'))
# mobileModel.add(layers.Dense(4, activation='softmax'))  # softmax is used as it is a multiclass problem

# # Compile the model
# mobileModel.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# mobileModel.summary()

# %% [markdown]
# # Training

# %%
steps_per_epoch = len(os.listdir(train_path))//4
val_steps_per_epoch = len(os.listdir(val_path))//2

tf.random.set_seed(42)
epoch = 10


# Save best model
weight_path = 'cnn_model/'

model_checkpoint = ModelCheckpoint(
    filepath = weight_path,
    save_best_only = True,
    save_weights_only = True,
    mode = 'max',
    monitor = 'val_accuracy',
    save_freq='epoch',
    verbose = 2
)

# %%
history = model.fit(train_dataset, 
                    epochs=epoch, 
                    validation_data=test_dataset, 
                    callbacks=[model_checkpoint]
                    )
# Out:
# Epoch 1/10
# 396/396 [==============================] - ETA: 0s - loss: 0.4572 - accuracy: 0.8258
# Epoch 1: val_accuracy improved from -inf to 0.76524, saving model to cnn_model\
# 396/396 [==============================] - 68s 148ms/step - loss: 0.4572 - accuracy: 0.8258 - val_loss: 0.7522 - val_accuracy: 0.7652
# Epoch 2/10
# 396/396 [==============================] - ETA: 0s - loss: 0.2051 - accuracy: 0.9323
# Epoch 2: val_accuracy improved from 0.76524 to 0.79248, saving model to cnn_model\
# 396/396 [==============================] - 56s 141ms/step - loss: 0.2051 - accuracy: 0.9323 - val_loss: 0.9856 - val_accuracy: 0.7925
# Epoch 3/10
# 396/396 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.9483
# Epoch 3: val_accuracy did not improve from 0.79248
# 396/396 [==============================] - 56s 140ms/step - loss: 0.1545 - accuracy: 0.9483 - val_loss: 0.9564 - val_accuracy: 0.7912
# Epoch 4/10
# 396/396 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.9629
# Epoch 4: val_accuracy did not improve from 0.79248
# 396/396 [==============================] - 55s 138ms/step - loss: 0.1200 - accuracy: 0.9629 - val_loss: 1.1388 - val_accuracy: 0.7873
# Epoch 5/10
# 396/396 [==============================] - ETA: 0s - loss: 0.0905 - accuracy: 0.9693
# Epoch 5: val_accuracy did not improve from 0.79248
# 396/396 [==============================] - 56s 142ms/step - loss: 0.0905 - accuracy: 0.9693 - val_loss: 1.1817 - val_accuracy: 0.7899
# Epoch 6/10
# 396/396 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9772
# Epoch 6: val_accuracy did not improve from 0.79248
# 396/396 [==============================] - 54s 137ms/step - loss: 0.0728 - accuracy: 0.9772 - val_loss: 1.4340 - val_accuracy: 0.7562
# Epoch 7/10
# 396/396 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9785
# Epoch 7: val_accuracy did not improve from 0.79248
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0628 - accuracy: 0.9785 - val_loss: 1.2212 - val_accuracy: 0.7536
# Epoch 8/10
# 396/396 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9777
# Epoch 8: val_accuracy did not improve from 0.79248
# 396/396 [==============================] - 54s 137ms/step - loss: 0.0622 - accuracy: 0.9777 - val_loss: 1.6181 - val_accuracy: 0.7795
# Epoch 9/10
# 396/396 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9862
# Epoch 9: val_accuracy did not improve from 0.79248
# 396/396 [==============================] - 52s 131ms/step - loss: 0.0416 - accuracy: 0.9862 - val_loss: 1.4006 - val_accuracy: 0.7821
# Epoch 10/10
# 396/396 [==============================] - ETA: 0s - loss: 0.0334 - accuracy: 0.9888
# Epoch 10: val_accuracy did not improve from 0.79248
# 396/396 [==============================] - 53s 134ms/step - loss: 0.0334 - accuracy: 0.9888 - val_loss: 1.6873 - val_accuracy: 0.7782

# %%
# history = mobileModel.fit(train_dataset,
#                           epochs=epoch,
#                           validation_data=val_dataset,
#                           callbacks=[model_checkpoint])

# %%
# history = resnetModel.fit(train_dataset, 
#                           epochs=epoch, 
#                           validation_data=val_dataset, 
#                           callbacks=[model_checkpoint])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epoch)

plt.figure(figsize=(13, 10))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Predictions

# %%
# load trained model

# model = models.load_model("lime-ray-cnn-lstm-20e.h5")

# %%
labels = ['COVID-19','NORMAL', 'PNEUMONIA', 'TURBERCULOSIS']


# load best weights to model
# model.load_weights(weight_path)

# make predictions
predictions = model.predict(test_dataset)
# we have to get the position of the maximum value from each sample.
predicted_class = np.argmax(predictions, axis=1)

from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

true_labels = test_dataset.classes
# Out:
# 49/49 [==============================] - 7s 122ms/step

# %%
cm = confusion_matrix(true_labels, predicted_class, 
                      normalize='all'
                      )
ConfusionMatrixDisplay(cm, display_labels=labels).plot(cmap='rocket')
plt.xticks(rotation=20)
plt.show()

# %%
# Print classification report

class_report = classification_report(true_labels, predicted_class, labels=[0, 1, 2, 3], target_names=labels, digits=4)
print(class_report)
# Out:
#                precision    recall  f1-score   support
#
#      COVID-19     0.9327    0.9151    0.9238       106
#        NORMAL     0.9390    0.3291    0.4873       234
#     PNEUMONIA     0.7199    0.9949    0.8353       390
# TURBERCULOSIS     0.8261    0.9268    0.8736        41
#
#      accuracy                         0.7782       771
#     macro avg     0.8544    0.7915    0.7800       771
#  weighted avg     0.8213    0.7782    0.7439       771

# %%
# model.save('lime-ray-cnn-lstm-20e.h5')

# %%
def singlePred(batch, im):


    actual_label = labels[np.argmax(test_dataset.__getitem__(idx=batch)[1][im])]
    pred_label = labels[np.argmax(model.predict(test_dataset.__getitem__(idx=batch)[0])[im])]


    plt.imshow(test_dataset.__getitem__(idx=batch)[0][im])
    plt.title(f"Actual Label: {actual_label} \n Predicted Label: {pred_label}")
    plt.show()
    
for i in range(3):
    singlePred(30,i)
# Out:
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
